# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''
# Out:
# '\nA Convolutional Network implementation example using TensorFlow library.\nThis example is using the MNIST database of handwritten digits\n(http://yann.lecun.com/exdb/mnist/)\n\nAuthor: Aymeric Damien\nProject: https://github.com/aymericdamien/TensorFlow-Examples/\n'

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 21284.191406, Training Accuracy= 0.16406
# Iter 2560, Minibatch Loss= 10120.499023, Training Accuracy= 0.51562
# Iter 3840, Minibatch Loss= 7841.580566, Training Accuracy= 0.60156
# Iter 5120, Minibatch Loss= 4162.875488, Training Accuracy= 0.79688
# Iter 6400, Minibatch Loss= 3109.224121, Training Accuracy= 0.79688
# Iter 7680, Minibatch Loss= 6950.587891, Training Accuracy= 0.72656
# Iter 8960, Minibatch Loss= 2693.669434, Training Accuracy= 0.82031
# Iter 10240, Minibatch Loss= 3045.892578, Training Accuracy= 0.81250
# Iter 11520, Minibatch Loss= 1672.632568, Training Accuracy= 0.90625
# Iter 12800, Minibatch Loss= 2240.449707, Training Accuracy= 0.83594
# Iter 14080, Minibatch Loss= 674.144714, Training Accuracy= 0.91406
# Iter 15360, Minibatch Loss= 1188.201538, Training Accuracy= 0.93750
# Iter 16640, Minibatch Loss= 1850.897705, Training Accuracy= 0.90625
# Iter 17920, Minibatch Loss= 742.163574, Training Accuracy= 0.92969
# Iter 19200, Minibatch Loss= 1381.246216, Training Accuracy= 0.91406
# Iter 20480, Minibatch Loss= 35.904938, Training Accuracy= 0.97656
# Iter 21760, Minibatch Loss= 2827.476074, Training Accuracy= 0.85938
# Iter 23040, Minibatch Loss= 1076.601074, Training Accuracy= 0.95312
# Iter 24320, Minibatch Loss= 858.597656, Training Accuracy= 0.89844
# Iter 25600, Minibatch Loss= 817.654846, Training Accuracy= 0.89844
# Iter 26880, Minibatch Loss= 500.401550, Training Accuracy= 0.92188
# Iter 28160, Minibatch Loss= 539.258728, Training Accuracy= 0.95312
# Iter 29440, Minibatch Loss= 891.105957, Training Accuracy= 0.92969
# Iter 30720, Minibatch Loss= 455.663635, Training Accuracy= 0.92188
# Iter 32000, Minibatch Loss= 601.155151, Training Accuracy= 0.94531
# Iter 33280, Minibatch Loss= 628.550720, Training Accuracy= 0.93750
# Iter 34560, Minibatch Loss= 563.227661, Training Accuracy= 0.92969
# Iter 35840, Minibatch Loss= 398.686096, Training Accuracy= 0.93750
# Iter 37120, Minibatch Loss= 1078.093018, Training Accuracy= 0.92969
# Iter 38400, Minibatch Loss= 98.103577, Training Accuracy= 0.97656
# Iter 39680, Minibatch Loss= 168.589188, Training Accuracy= 0.96875
# Iter 40960, Minibatch Loss= 1667.168701, Training Accuracy= 0.89844
# Iter 42240, Minibatch Loss= 736.923157, Training Accuracy= 0.89844
# Iter 43520, Minibatch Loss= 575.511963, Training Accuracy= 0.97656
# Iter 44800, Minibatch Loss= 467.877106, Training Accuracy= 0.94531
# Iter 46080, Minibatch Loss= 214.065338, Training Accuracy= 0.97656
# Iter 47360, Minibatch Loss= 1071.597412, Training Accuracy= 0.92969
# Iter 48640, Minibatch Loss= 1157.630615, Training Accuracy= 0.90625
# Iter 49920, Minibatch Loss= 482.730530, Training Accuracy= 0.92969
# Iter 51200, Minibatch Loss= 172.511795, Training Accuracy= 0.97656
# Iter 52480, Minibatch Loss= 296.914337, Training Accuracy= 0.93750
# Iter 53760, Minibatch Loss= 196.551804, Training Accuracy= 0.97656
# Iter 55040, Minibatch Loss= 819.128967, Training Accuracy= 0.96094
# Iter 56320, Minibatch Loss= 185.061630, Training Accuracy= 0.95312
# Iter 57600, Minibatch Loss= 483.189087, Training Accuracy= 0.93750
# Iter 58880, Minibatch Loss= 496.009979, Training Accuracy= 0.96094
# Iter 60160, Minibatch Loss= 535.943176, Training Accuracy= 0.94531
# Iter 61440, Minibatch Loss= 424.781311, Training Accuracy= 0.94531
# Iter 62720, Minibatch Loss= 176.489655, Training Accuracy= 0.96875
# Iter 64000, Minibatch Loss= 554.067871, Training Accuracy= 0.96875
# Iter 65280, Minibatch Loss= 166.315109, Training Accuracy= 0.95312
# Iter 66560, Minibatch Loss= 275.475525, Training Accuracy= 0.96094
# Iter 67840, Minibatch Loss= 263.772827, Training Accuracy= 0.96094
# Iter 69120, Minibatch Loss= 584.040771, Training Accuracy= 0.96094
# Iter 70400, Minibatch Loss= 926.066040, Training Accuracy= 0.89844
# Iter 71680, Minibatch Loss= 1027.533325, Training Accuracy= 0.94531
# Iter 72960, Minibatch Loss= 441.024933, Training Accuracy= 0.96094
# Iter 74240, Minibatch Loss= 331.021667, Training Accuracy= 0.95312
# Iter 75520, Minibatch Loss= 643.609680, Training Accuracy= 0.93750
# Iter 76800, Minibatch Loss= 616.823303, Training Accuracy= 0.93750
# Iter 78080, Minibatch Loss= 393.905701, Training Accuracy= 0.95312
# Iter 79360, Minibatch Loss= 131.253632, Training Accuracy= 0.97656
# Iter 80640, Minibatch Loss= 706.152466, Training Accuracy= 0.92969
# Iter 81920, Minibatch Loss= 594.090637, Training Accuracy= 0.94531
# Iter 83200, Minibatch Loss= 464.349731, Training Accuracy= 0.94531
# Iter 84480, Minibatch Loss= 519.587402, Training Accuracy= 0.93750
# Iter 85760, Minibatch Loss= 174.313766, Training Accuracy= 0.96875
# Iter 87040, Minibatch Loss= 276.295898, Training Accuracy= 0.97656
# Iter 88320, Minibatch Loss= 584.218384, Training Accuracy= 0.97656
# Iter 89600, Minibatch Loss= 494.408722, Training Accuracy= 0.94531
# Iter 90880, Minibatch Loss= 267.489288, Training Accuracy= 0.96094
# Iter 92160, Minibatch Loss= 263.031982, Training Accuracy= 0.97656
# Iter 93440, Minibatch Loss= 3.592712, Training Accuracy= 0.99219
# Iter 94720, Minibatch Loss= 205.319885, Training Accuracy= 0.96875
# Iter 96000, Minibatch Loss= 356.740112, Training Accuracy= 0.92969
# Iter 97280, Minibatch Loss= 451.565460, Training Accuracy= 0.96094
# Iter 98560, Minibatch Loss= 177.536926, Training Accuracy= 0.96875
# Iter 99840, Minibatch Loss= 241.377075, Training Accuracy= 0.96094
# Iter 101120, Minibatch Loss= 1221.142944, Training Accuracy= 0.92969
# Iter 102400, Minibatch Loss= 192.253494, Training Accuracy= 0.97656
# Iter 103680, Minibatch Loss= 279.375183, Training Accuracy= 0.96875
# Iter 104960, Minibatch Loss= 85.725807, Training Accuracy= 0.98438
# Iter 106240, Minibatch Loss= 314.944519, Training Accuracy= 0.94531
# Iter 107520, Minibatch Loss= 299.908569, Training Accuracy= 0.96094
# Iter 108800, Minibatch Loss= 370.669434, Training Accuracy= 0.95312
# Iter 110080, Minibatch Loss= 427.804626, Training Accuracy= 0.96875
# Iter 111360, Minibatch Loss= 134.506256, Training Accuracy= 0.97656
# Iter 112640, Minibatch Loss= 74.175735, Training Accuracy= 0.97656
# Iter 113920, Minibatch Loss= 147.573196, Training Accuracy= 0.97656
# Iter 115200, Minibatch Loss= 213.371780, Training Accuracy= 0.95312
# Iter 116480, Minibatch Loss= 647.469910, Training Accuracy= 0.91406
# Iter 117760, Minibatch Loss= 38.946651, Training Accuracy= 0.99219
# Iter 119040, Minibatch Loss= 104.848297, Training Accuracy= 0.99219
# Iter 120320, Minibatch Loss= 150.330963, Training Accuracy= 0.96094
# Iter 121600, Minibatch Loss= 411.518127, Training Accuracy= 0.95312
# Iter 122880, Minibatch Loss= 161.082825, Training Accuracy= 0.96875
# Iter 124160, Minibatch Loss= 354.391052, Training Accuracy= 0.93750
# Iter 125440, Minibatch Loss= 386.901672, Training Accuracy= 0.97656
# Iter 126720, Minibatch Loss= 111.808052, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 440.753265, Training Accuracy= 0.95312
# Iter 129280, Minibatch Loss= 166.661041, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 258.877350, Training Accuracy= 0.98438
# Iter 131840, Minibatch Loss= 429.144867, Training Accuracy= 0.94531
# Iter 133120, Minibatch Loss= 102.048553, Training Accuracy= 0.98438
# Iter 134400, Minibatch Loss= 242.080185, Training Accuracy= 0.98438
# Iter 135680, Minibatch Loss= 256.457123, Training Accuracy= 0.97656
# Iter 136960, Minibatch Loss= 135.563293, Training Accuracy= 0.97656
# Iter 138240, Minibatch Loss= 61.883873, Training Accuracy= 0.97656
# Iter 139520, Minibatch Loss= 228.932526, Training Accuracy= 0.98438
# Iter 140800, Minibatch Loss= 217.557907, Training Accuracy= 0.96875
# Iter 142080, Minibatch Loss= 514.992798, Training Accuracy= 0.94531
# Iter 143360, Minibatch Loss= 37.930763, Training Accuracy= 0.98438
# Iter 144640, Minibatch Loss= 45.236221, Training Accuracy= 0.98438
# Iter 145920, Minibatch Loss= 80.496307, Training Accuracy= 0.97656
# Iter 147200, Minibatch Loss= 90.853348, Training Accuracy= 0.97656
# Iter 148480, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 149760, Minibatch Loss= 632.968872, Training Accuracy= 0.96094
# Iter 151040, Minibatch Loss= 179.734344, Training Accuracy= 0.98438
# Iter 152320, Minibatch Loss= 168.388046, Training Accuracy= 0.96094
# Iter 153600, Minibatch Loss= 241.133408, Training Accuracy= 0.97656
# Iter 154880, Minibatch Loss= 324.310608, Training Accuracy= 0.92969
# Iter 156160, Minibatch Loss= 128.558487, Training Accuracy= 0.95312
# Iter 157440, Minibatch Loss= 104.004044, Training Accuracy= 0.98438
# Iter 158720, Minibatch Loss= 150.428375, Training Accuracy= 0.96875
# Iter 160000, Minibatch Loss= 170.039536, Training Accuracy= 0.99219
# Iter 161280, Minibatch Loss= 193.225372, Training Accuracy= 0.97656
# Iter 162560, Minibatch Loss= 248.018326, Training Accuracy= 0.96875
# Iter 163840, Minibatch Loss= 223.458740, Training Accuracy= 0.96094
# Iter 165120, Minibatch Loss= 239.561646, Training Accuracy= 0.97656
# Iter 166400, Minibatch Loss= 275.320984, Training Accuracy= 0.97656
# Iter 167680, Minibatch Loss= 230.038879, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 151.898392, Training Accuracy= 0.96875
# Iter 170240, Minibatch Loss= 143.009796, Training Accuracy= 0.96875
# Iter 171520, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 172800, Minibatch Loss= 79.021271, Training Accuracy= 0.98438
# Iter 174080, Minibatch Loss= 19.977905, Training Accuracy= 0.99219
# Iter 175360, Minibatch Loss= 31.272018, Training Accuracy= 0.98438
# Iter 176640, Minibatch Loss= 61.786842, Training Accuracy= 0.97656
# Iter 177920, Minibatch Loss= 7.848938, Training Accuracy= 0.99219
# Iter 179200, Minibatch Loss= 204.568985, Training Accuracy= 0.97656
# Iter 180480, Minibatch Loss= 19.162476, Training Accuracy= 0.99219
# Iter 181760, Minibatch Loss= 11.936157, Training Accuracy= 0.96875
# Iter 183040, Minibatch Loss= 68.797501, Training Accuracy= 0.97656
# Iter 184320, Minibatch Loss= 91.599693, Training Accuracy= 0.99219
# Iter 185600, Minibatch Loss= 11.723854, Training Accuracy= 0.99219
# Iter 186880, Minibatch Loss= 17.352524, Training Accuracy= 0.99219
# Iter 188160, Minibatch Loss= 121.575935, Training Accuracy= 0.98438
# Iter 189440, Minibatch Loss= 91.836899, Training Accuracy= 0.98438
# Iter 190720, Minibatch Loss= 24.878967, Training Accuracy= 0.99219
# Iter 192000, Minibatch Loss= 236.065308, Training Accuracy= 0.97656
# Iter 193280, Minibatch Loss= 130.424057, Training Accuracy= 0.97656
# Iter 194560, Minibatch Loss= 228.347839, Training Accuracy= 0.96094
# Iter 195840, Minibatch Loss= 70.880096, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 26.769623, Training Accuracy= 0.98438
# Iter 198400, Minibatch Loss= 251.461884, Training Accuracy= 0.96875
# Iter 199680, Minibatch Loss= 143.164337, Training Accuracy= 0.96094
# Optimization Finished!
# Testing Accuracy: 0.976562
