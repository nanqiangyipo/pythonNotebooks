# %%
import numpy as np

# %%
X=np.ndarray((11,11,4))

# %%
X.shape
# Out:
# (11, 11, 4)

# %%
X[:,:,0]
# Out:
# array([[  6.96407597e+252,   2.87249161e+161,   2.25563609e-153,
#           3.16161183e-086,   9.85330622e+165,   6.01334541e-154,
#           1.67709717e+243,   1.33767382e+160,   9.29644519e-247,
#           4.85213860e-308,   1.33299742e+185],
#        [  1.81314593e-312,   1.14303493e+243,   1.79209176e-313,
#           1.73073372e-308,   2.85308965e-313,   4.28260871e+286,
#           3.60662350e+228,   1.38222562e-309,   6.21822213e+175,
#           8.33044493e-251,   4.12267764e-218],
#        [  4.98330981e+173,   1.93390501e-309,   5.12543983e-143,
#          -2.05997975e-289,   2.41846439e-308,   2.90092712e-215,
#           3.47412289e+010,   1.39806875e-152,   7.86023809e+165,
#          -6.59191079e+125,   1.50762010e+161],
#        [  1.96100082e+243,   8.16742000e+197,   9.69723733e+189,
#           4.02254573e+178,   2.77526084e-285,  -2.73435345e+127,
#           8.82822663e+199,   2.14120501e+243,   4.24399158e-314,
#           4.96944344e-297,   6.19283256e-309],
# ...
