# %%
from PIL import Image
import numpy as np
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %% [markdown]
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/0f8c03ecb4b845478aaf1da6e5359132.png
# 啊呀呀呀，异常240000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/2aecf8ff77b74a39b801976056e8a510.gif
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/0f899c2230c64d6eaeafe8a3ad9cc5b0.png
# 啊呀呀呀，异常240000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/1e6b44eea24b4c0cb73a98b94492e9ed.gif
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/1c6fa179c77a4ea7abf93374a10c1f5a.png
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/0da2c0267e2d4cc68d0ba9cee732b8d3.png
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/0f997e0d9b5e4687829a3ae41da7dd30.png
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/2a31169cbff243e89eef69a2b125e5d9.png
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/0b999065db2c4c4c9f9b26aa88093c95.png
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/0e9efa87ecec4750b41ae9846b233073.png
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/1dc1288075ad4a7599bd3f7eee2597d6.png
# 啊呀呀呀，异常240000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/0d08408b37bb4b0e928ab3785f143c26.gif
# 啊呀呀呀，异常240000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/1aa7d07e2eed4a1a82a02d60425c4e86.gif
# 啊呀呀呀，异常240000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/2a848533caa9487db55399ed1ce632fe.gif
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/2b404d3859f14fd2b970e8533a91c787.png
# 啊呀呀呀，异常240000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/1ebb145ce5304038817e2370e9b9c3ae.gif
# 啊呀呀呀，异常960000--/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/2ab378ac843c47d8aff210459677b26f.png

# %%
p1=r'/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/0f8c03ecb4b845478aaf1da6e5359132.png'
p2=r'/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/1ebb145ce5304038817e2370e9b9c3ae.gif'
p3=r'/home/xinye/PycharmProjects/PyCodeFragment/data/resized_animal/狗/2aecf8ff77b74a39b801976056e8a510.gif'
p4=r'/home/xinye/PycharmProjects/PyCodeFragment/util/image.jpg'

# %%
i1=Image.open(p1)
i2=Image.open(p2)
i3=Image.open(p3)
i4=Image.open(p4)

# %%
help(plt.subplots_adjust)

# %%
height=3
wide=2
# 设置子图之间的距离
plt.subplots_adjust(top=1.5)

# 绘制子图，格子大小为height,wide
plt.subplot(height,wide,1)
plt.imshow(np.asanyarray(i1))
plt.title('i1')

plt.subplot(height,wide,2)
plt.imshow(i2)
plt.title('i2')

plt.subplot(height,wide,3)
plt.imshow(i3)
plt.title('i3')


plt.subplot(height,wide,4)
plt.imshow(np.asanyarray(i2))
plt.title('i2')

plt.subplot(height,wide,5)
plt.imshow(np.asanyarray(i4))
plt.title('i4')

# %%
print(
    np.asanyarray(i1).shape,
    np.asanyarray(i2).shape,
    np.asanyarray(i3).shape,
    np.asanyarray(i4).shape
    )
print(
    i2.mode,
    i2.format
    )
# Out:
# (400, 600, 4) (400, 600) (400, 600) (400, 600, 3)
# P GIF

# %%
# gif转jpg  将png转为jpg只需要将
i3.convert('RGB').save(r'/home/xinye/PycharmProjects/PyCodeFragment/util/image.jpg')

# %%
i1.save(r'/home/xinye/PycharmProjects/PyCodeFragment/util/image.jpg')
